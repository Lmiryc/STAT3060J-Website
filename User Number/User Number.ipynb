# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline
import plotly.express as px

# %%
articles = pd.read_csv('./data/articles.CSV',encoding='gb2312')
buttons = pd.read_csv('./data/buttons.CSV',encoding='gb2312')
content = pd.read_csv('./data/content_statistics.CSV',encoding='gb2312')
key_words = pd.read_csv('./data/key_words.CSV',encoding='gb2312')
message = pd.read_csv('./data/message.CSV',encoding='gb2312')
users = pd.read_csv('./data/users.CSV',encoding='gb2312')

# %%
articles.sort_values('总阅读人数')
# Out:
#                                      内容标题      发表时间  总阅读人数  总阅读次数  总分享人数  \
# 22                        【你呼我应】你有所呼，我有所应  20221024    168    213      8
# 19                      金山街道居民生活物资采购渠道告知书  20221025    205    225      3
# 11                 防疫科普 | 满满的干货！科学消毒，你问我答  20221202    233    271      4
# 21  仓山区新型冠状病毒感染肺炎疫情防控工作应急指挥部通告（2022年第31号）  20221024    274    320     12
# 18  仓山区新型冠状病毒感染肺炎疫情防控工作应急指挥部通告（2022年第33号）  20221025    310    361      6
# 8                       一图看懂！不同人群健康防护指南来了  20221208    443    509     28
# 3           冬至福利 | 免费水果第二波火爆开启，还没参加的请速度啦!  20221222    637    785     22
# 7                           抗原自测怎么测？教程来了！  20221208    656    775     41
# 2      防疫科普 | 一直咳嗽怎么办？被子会传播病毒吗？居家康复20问20答  20221222    726    858     38
# 1       核酸检测 | 仓山区“防疫便民地图”升级啦！单管！混管！一目了然！  20221222   1118   1346     29
# 5                        送福利啦！爱心水果免费送~快抢~  20221215   1324   1854     75
# 24                       速看！转发！福州最新核酸采样点位  20221023   1572   2053     96
# 16                  一键导航！仓山区“核酸采样点位图”上线啦！  20221103   2074   2485     87
# 23                      金山街道关于开展核酸检测演练的通告  20221023   2223   3077    112
# 17                   金山街道关于开展第三次核酸检测演练的通告  20221025   2231   2744     99
# 10        仓山区关于开展新一轮区域核酸检测的通告（2022年第136号）  20221202   2377   2900     20
# 15    【周知】@水都、建中、六江道居民群众，金山街道居民健康信息，请您填报！  20221103   3587   5165    111
# 6                新型冠状病毒阳性感染者居家康复专家指引（第一版）  20221208   3649   4452    329
# 9                           金山街道致在外乡亲的一封信  20221202   4692   5317    107
# 12                       最新通知！事关金山街道核酸检测！  20221116   6318   7225     76
# 4                   仓山区部分常态化核酸采样点新增单人单管服务  20221215   6649   8991    362
# 0                   阳了怎么办？金山街道发热诊室联系方式公布！  20221222   8305  10481    559
# 14         【疫情防控】主动报备很重要！――给金山街道全体居民的报备指南  20221106  11879  16493    233
# 20                   金山街道关于开展第二次核酸检测演练的通告  20221024  12218  17159    714
# 13                       致金山街道全体居民朋友们的一封信  20221112  12398  13973    152
#
#     总分享次数  阅读后关注人数   送达人数  公众号消息阅读次数   送达阅读率  首次分享次数  分享产生阅读次数   首次分享率  \
# 22      9        1   1524         47  0.0308       4       131  0.0851
# 19      3        1   1819        125  0.0687       3         6  0.0240
# 11      4        0  44117        241  0.0055       4        17  0.0166
# 21     12        0   1524         92  0.0604       6       173  0.0652
# 18      7        1   1819         73  0.0401       2       196  0.0274
# 8      30        0  43986        376  0.0085      27        99  0.0718
# 3      23        1  43850        568  0.0130      17       147  0.0299
# 7      45        0  43986        594  0.0135      36       130  0.0606
# 2      47        0  43850        643  0.0147      42       175  0.0653
# 1      31        3  43850        872  0.0199      19       377  0.0218
# 5      93        4  43750        686  0.0157      35      1097  0.0510
# 24    121        1   1499        334  0.2228      36      1667  0.1078
# 16    110       28   2325        199  0.0856       6      1973  0.0302
# 23    140       20   1499        323  0.2155      32      2656  0.0991
# 22                        【你呼我应】你有所呼，我有所应  20221024    168   1524
# 23                      金山街道关于开展核酸检测演练的通告  20221023   2223   1499
# 24                       速看！转发！福州最新核酸采样点位  20221023   1572   1499

# %%
def remove_yr(s):
    str=''
    for i in range(5,len(s)):
        str+=s[i]
    return str
def remove_yr2(s):
    s=str(s)
    string=''
    for i in range(4,8):
        if i==6 and s[i]=='0':
            continue
        string+=s[i]
        if i==5:
            string+='/'
    return string
def markers_cnt(s):
    s=s%10000
    if s<1100 :
        return s-1000
    elif s<1200:
        return s-1100+31
    else:
        return s-1200+31+30
    
short_date=users['时间'].apply(remove_yr)
markers_on=articles['发表时间'].apply(markers_cnt)
markers_on
# Out:
# 0     83
# 1     83
# 2     83
# 3     83
# 4     76
# 5     76
# 6     69
# 7     69
# 8     69
# 9     63
# 10    63
# 11    63
# 12    47
# 13    43
# 14    37
# 15    34
# 16    34
# 17    25
# 18    25
# 19    25
# 20    24
# 21    24
# 22    24
# 23    23
# 24    23
# Name: 发表时间, dtype: int64

# %%
#准备绘制数据
plt.rcParams["font.sans-serif"]="Times New Roman"
plt.rcParams["axes.unicode_minus"]=False
x = short_date
y = users['累积关注人数']
plt.figure(dpi=300, figsize=(7, 5))
# "g" 表示红色，marksize用来设置'D'菱形的大小
plt.plot(x, y, "g", marker=',')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(14.8))

#

#绘制坐标轴标签
plt.xlabel("Date", fontsize=14)
plt.ylabel("The number of users", fontsize=14)
plt.title("Trend of the number of users", fontsize=14)
plt.savefig("./Trend of the number of users.png")
plt.show()

# %%
#准备绘制数据
plt.rcParams["font.sans-serif"]="Times New Roman"
plt.rcParams["axes.unicode_minus"]=False
plt.figure(dpi=300, figsize=(8, 6))
x = short_date
y = users['净增关注人数']

# "g" 表示红色，marksize用来设置'D'菱形的大小
plt.plot(x, y, "-cD",markevery=markers_on,label='Article release date')

plt.ylim(-300,300)
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(15))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(50))


#绘制坐标轴标签
plt.xlabel("Date", fontsize=16)
plt.ylabel("Net increase of the number of users", fontsize=16)
plt.title("Trend of net increase of the number of users", fontsize=16)

#显示图例
plt.legend(loc="lower right")
plt.grid()
plt.savefig("Trend of net increase.png")
plt.show()

# %%
#准备绘制数据
plt.rcParams["font.sans-serif"]="Times New Roman"
plt.rcParams["axes.unicode_minus"]=False

x = short_date
y = users['净增关注人数']
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.subplots_adjust(hspace=0.05)  

# plot the same data on both axes
ax1.plot(x, y, "-cD",markevery=markers_on,label='Article release date')
ax2.plot(x, y, "-cD",markevery=markers_on,label='Article release date')

plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(15))
plt.gca().yaxis.set_major_locator(ticker.MultipleLocator(50))

# zoom-in / limit the view to different portions of the data
ax2.set_ylim(-300,300)  # outliers only
ax1.set_ylim(600,11000)  # most of the data

# hide the spines between ax and ax2
ax1.spines.bottom.set_visible(False)
ax2.spines.top.set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)  
ax2.xaxis.tick_bottom()


d = .5  
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

plt.xlabel("Date", fontsize=16)
plt.legend(loc="lower right")
ax1.grid()
ax2.grid()
plt.savefig("./Completed.png")
plt.show()
